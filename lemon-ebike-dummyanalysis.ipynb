# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/JoshuaDamanik/Desktop/my-projects/dummycomplianceanalysis/lemon_ebike_data.csv')

# %%
df['Total_Fix_Time_Hours'] = (df['Issues_Per_Bike_Avg'] * df['Current_Fleet_Size'] * df['Fix_Time_Minutes_Avg']) / 60

# %%
df.plot(kind='bar', x='Bike_Model', y='Total_Fix_Time_Hours'); plt.show()
